# %%
import pandas as pd
import os

# %%
path_1 = ('/mnt/HC_Volume_18315164/home-jupyter/jupyter-a-a-30/mini_project4/4_inn.xls')
path_2 = ('/mnt/HC_Volume_18315164/home-jupyter/jupyter-a-a-30/mini_project4/4_necessary_inn.txt')

# %%
df_1 = pd.read_excel(path_1)
df_1
# Out:
#       Unnamed: 0     #                                    name     reg_number  \
# 0              0     0         ЗАО «Власова, Макаров и Шашков»  1143692580560
# 1              1     1  РАО «Тимофеева, Алексеева и Кузнецова»  9342309660697
# 2              2     2                      РАО «Юдин-Ефимова»  1277485323451
# 3              3     3                   Доронин Инкорпорэйтед  7139161431511
# 4              4     4    Объединенная энергетическая компания  6114798049639
# ...          ...   ...                                     ...            ...
# 2105        2105  2105         ИП «Зайцев, Шубин и Дементьева»  6580539599719
# 2106        2106  2106                               Юдина Лтд  5012825137426
# 2107        2107  2107                        Антонова Лимитед  7659150538516
# 2108        2108  2108                    ООО «Хохлов Казаков»  9506828156265
# 2109        2109  2109                  ИП «Кабанов Ситникова»  5283860848622
#
# ...

# %%
df_2 = pd.read_csv(path_2, header = None, squeeze=True)
df_2.astype(int)
df_2
# Out:
# 0      394609645484
# 1      281578625230
# 2      923769811917
# 3      998694734508
# 4      271011690615
#            ...
# 110    664306216794
# 111    991951385204
# 112    129413497752
# 113    447901012904
# 114    634037614688
# Name: 0, Length: 115, dtype: int64

# %%
aggregation = df_1.query('head_inn in @df_2')
aggregation.groupby('#').agg({'income,RUB':'sum'})
# Out:
#        income,RUB
# #
# 47    67534335517
# 76    19932336080
# 77     3103853229
# 85     8607813826
# 90    29181260019
# ...           ...
# 2059   9608612080
# 2074   7246816762
# 2089  48323910899
# 2106  67450329265
# 2108  85023560472
#
# [115 rows x 1 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     187             if self.has_resolvers:
# --> 188                 return self.resolvers[key]
#     189
#
# /opt/tljh/user/lib/python3.7/collections/__init__.py in __getitem__(self, key)
#     913                 pass
# --> 914         return self.__missing__(key)            # support subclasses that define __missing__
#     915
#
# /opt/tljh/user/lib/python3.7/collections/__init__.py in __missing__(self, key)
#     905     def __missing__(self, key):
# --> 906         raise KeyError(key)
#     907
#
# KeyError: 'income'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...
