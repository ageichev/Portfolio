# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('transaction_data_updated.csv')
df['minute'] = pd.to_datetime(df['date'])
true_minute = df.value_counts('minute')

# %%
df.value_counts('minute').to_frame()
# Out:
#                      0
# minute
# 2020-03-02 00:33:10  6
# 2020-03-02 00:35:03  6
# 2020-03-02 00:29:11  5
# 2020-03-02 00:02:31  5
# 2020-03-02 00:56:00  5
# ...                 ..
# 2020-03-02 00:50:47  1
# 2020-03-02 00:50:45  1
# 2020-03-02 00:50:44  1
# 2020-03-02 00:50:41  1
# 2020-03-02 00:00:00  1
#
# [3373 rows x 1 columns]

# %%
minutes = df.groupby(['name', 'minute'], as_index = False) \
    .agg({'transaction':'count'})
user_vs_minute_pivot = minutes.pivot(index = 'minute', columns='name', values='transaction')
user_vs_minute_pivot.fillna(0)
# Out:
# name    Ekaterina_Fedorova  Ekaterina_Ivanova  Ekaterina_Lesnova  \
# minute
# 0                      3.0                4.0                2.0
# 1                      4.0                4.0                0.0
# 2                      1.0                2.0                4.0
# 3                      3.0                0.0                2.0
# 4                      3.0                0.0                0.0
# 5                      3.0                0.0                2.0
# 6                      4.0                1.0                2.0
# 7                      3.0                2.0                1.0
# 8                      2.0                4.0                3.0
# 9                      2.0                4.0                2.0
# 10                     0.0                3.0                3.0
# 11                     2.0                3.0                3.0
# 12                     4.0                3.0                0.0
# ...
