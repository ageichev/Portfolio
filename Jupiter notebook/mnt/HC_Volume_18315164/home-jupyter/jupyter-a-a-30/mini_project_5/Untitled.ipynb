# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-a-a-30/mini_project_5/transaction_data.csv')
df
# Out:
#                      date                name  transaction
# 0     2020-03-02 00:37:20   Ekaterina_Petrova    cancelled
# 1     2020-03-02 00:59:09      Irina_Fedorova  successfull
# 2     2020-03-02 01:06:14  Ekaterina_Smirnova  successfull
# 3     2020-03-02 00:02:58    Lolita_Polyanova    cancelled
# 4     2020-03-02 00:17:52      Julia_Smirnova    cancelled
# ...                   ...                 ...          ...
# 5310  2020-03-02 00:09:28   Vasilisa_Fedorova  successfull
# 5311  2020-03-02 00:46:31    Vasilisa_Ozerova  successfull
# 5312  2020-03-02 00:16:38      Olga_Polyanova  successfull
# 5313  2020-03-02 00:13:00  Ekaterina_Smirnova  successfull
# 5314  2020-03-02 01:15:45      Irina_Fedorova    cancelled
#
# [5315 rows x 3 columns]

# %%
df.shape
# Out:
# (5315, 3)

# %%
df.dtypes
# Out:
# date           object
# name           object
# transaction    object
# dtype: object

# %%
df.isna().sum()
# Out:
# date           0
# name           0
# transaction    0
# dtype: int64

# %%
df.transaction.unique()
# Out:
# array(['cancelled', 'successfull', 'error'], dtype=object)

# %%
df.transaction.value_counts().plot.bar()

# %%
df.transaction.value_counts()
# Out:
# successfull    3692
# cancelled      1619
# error             4
# Name: transaction, dtype: int64

# %%
visual = df.query('transaction == "successfull"').groupby('name', as_index=False).agg({'transaction':'count'})
visual
# Out:
#                    name  transaction
# 0    Ekaterina_Fedorova           72
# 1     Ekaterina_Ivanova           59
# 2     Ekaterina_Lesnova           63
# 3     Ekaterina_Ozerova           72
# 4     Ekaterina_Petrova           68
# 5   Ekaterina_Polyanova           68
# 6    Ekaterina_Smirnova           77
# 7        Irina_Fedorova           62
# 8         Irina_Ivanova           60
# 9         Irina_Lesnova           76
# 10        Irina_Ozerova           76
# 11        Irina_Petrova           66
# 12      Irina_Polyanova           59
# 13       Irina_Smirnova           63
# 14       Julia_Fedorova           67
# 15        Julia_Ivanova           63
# 16        Julia_Lesnova           55
# 17        Julia_Ozerova           60
# 18        Julia_Petrova           74
# 19      Julia_Polyanova           61
# 20       Julia_Smirnova           67
# 21      Lolita_Fedorova           70
# 22       Lolita_Ivanova           76
# 23       Lolita_Lesnova           52
# ...

# %%
sns.displot(visual.transaction)

# %%
visual.describe()
# Out:
#        transaction
# count    56.000000
# mean     65.928571
# std       7.787769
# min      46.000000
# 25%      61.000000
# 50%      64.000000
# 75%      72.000000
# max      82.000000
