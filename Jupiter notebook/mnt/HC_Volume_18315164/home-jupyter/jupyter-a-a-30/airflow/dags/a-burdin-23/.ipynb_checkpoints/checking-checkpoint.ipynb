# %%
import pandas as pd
import numpy as np

# %%
TOP_1M_DOMAINS = 'http://s3.amazonaws.com/alexa-static/top-1m.csv.zip'
TOP_1M_DOMAINS_FILE = 'top-1m.csv'

# %%
def get_data():
    # Здесь пока оставили запись в файл, как передавать переменую между тасками будет в третьем уроке
    top_doms = pd.read_csv(TOP_1M_DOMAINS)
    top_data = top_doms.to_csv(index=False)

    with open(TOP_1M_DOMAINS_FILE, 'w') as f:
        f.write(top_data)

# %%
df=pd.read_csv(TOP_1M_DOMAINS_FILE, names=['rank', 'domain'])

# %%
df.head(3)
# Out:
#    rank       domain
# 0     1   google.com
# 1     2  youtube.com
# 2     3    baidu.com

# %% [markdown]
# Найти топ-10 доменных зон по численности доменов

# %%
df['domain_ends'] = df['domain'].apply(lambda x: x.split('.')[-1])

# %%
df.head()
# Out:
#    rank        domain domain_ends
# 0     1    google.com         com
# 1     2   youtube.com         com
# 2     3     baidu.com         com
# 3     4  facebook.com         com
# 4     5      bing.com         com

# %%
df_top_domains = df.groupby(["domain_ends"], as_index=False).agg({"domain":"count"}).sort_values("domain", ascending=False).head(10)
df_top_domains
# Out:
#     domain_ends  domain
# 143         com  341680
# 469         org   27794
# 441         net   26252
# 534          ru   15379
# 169          de   11175
# 325          ir   10134
# 32           au   10092
# 452          nl    9748
# 651          uk    9024
# 329          it    7998

# %% [markdown]
# Найти домен с самым длинным именем (если их несколько, то взять только первый в алфавитном порядке)

# %%
lengths = df["domain"].str.len()
argmax = np.where(lengths == lengths.max())[-1]
df.iloc[argmax]
# Out:
#           rank                                             domain domain_ends
# 159590  159591  file-service-default-114c67af0763a8a98e770ff3e...         com

# %% [markdown]
# На каком месте находится домен airflow.com?

# %%
numb = pd.DataFrame(df[df.domain.str.contains("airflow.com")].index.values.astype(int))

# %%
print(numb)
# Out:
#         0
# 0  425641

# %%
numb1 = df[df.domain.str.contains("airflow.com")].index.values.astype(int).tolist()
numb1.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-0a1d506e2f51> in <module>
#       1 numb1 = df[df.domain.str.contains("airflow.com")].index.values.astype(int).tolist()
# ----> 2 numb1.info()
#
# AttributeError: 'list' object has no attribute 'info'

# %%
dd = pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-a-burdin-23/DAGs/airflow/dags/a.batalov/vgsales.csv')
dd
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
dd.Name.unique
# Out:
# <bound method Series.unique of 0                                              Wii Sports
# 1                                       Super Mario Bros.
# 2                                          Mario Kart Wii
# 3                                       Wii Sports Resort
# 4                                Pokemon Red/Pokemon Blue
#                                ...
# 16593                  Woody Woodpecker in Crazy Castle 5
# 16594                       Men in Black II: Alien Escape
# 16595    SCORE International Baja 1000: The Official Game
# 16596                                          Know How 2
# 16597                                    Spirits & Spells
# Name: Name, Length: 16598, dtype: object>

# %%
path2file = '/mnt/HC_Volume_18315164/home-jupyter/jupyter-a-burdin-23/DAGs/airflow/dags/a.batalov/vgsales.csv'

# %%
login = 'a-burdin-23'

# %%
year = 1994 + hash(f'{login}') % 23
year
# Out:
# 1999

# %%
def get_data():
    df = pd.read_csv(path2file)
    df = df.query("Year == @year")
    #df.Year = df.Year.astype('int') 
    return df

# %%
#Какая игра была самой продаваемой в этом году во всем мире?
#@task()
def bestseller_game(df):
    bestseller_game_res = df.sort_values('Global_Sales', ascending=False).iloc[0].Name
    return bestseller_game_res

# %%
bestseller_game(get_data())
# Out:
# 'Pokemon Gold/Pokemon Silver'

# %%
#Игры какого жанра были самыми продаваемыми в Европе? Перечислить все, если их несколько
#@task()
def bestseller_games_euro(df):
    result = df.groupby(["Genre"], as_index=False).agg({"EU_Sales":"sum"}).sort_values("EU_Sales", ascending=False)
    bestseller_games_euro_res = ', '.join(result.Genre.tolist())    
    return bestseller_games_euro_res

# %%
bestseller_games_euro(get_data())
# Out:
# 'Role-Playing, Racing, Action, Sports, Platform, Strategy, Misc, Shooter, Adventure, Fighting, Simulation, Puzzle'

# %%
# На какой платформе было больше всего игр, которые продались более чем миллионным тиражом в Северной Америке?
# Перечислить все, если их несколько
#@task()
def million_platform_na(df):
    df['MoreThan1M'] = df.NA_Sales > 1.0
    million_platform_na_res = df.groupby(["Platform"], as_index=False)['NA_Sales']\
    .agg({"MoreThan1M":"sum"}).sort_values("MoreThan1M", ascending=False)
    return million_platform_na_res

# %%
million_platform_na(get_data())
# Out:
#   Platform  MoreThan1M
# 4       PS       65.94
# 2      N64       38.77
# 1       GB       16.21
# 3       PC        3.50
# 0       DC        1.64
# 5      SAT        0.00
# 6     SNES        0.00
# 7       WS        0.00

# %%
# У какого издателя самые высокие средние продажи в Японии?
# Перечислить все, если их несколько
#@task()
def best_publisher_jp(df):
    best_publisher_jp = df.groupby(["Publisher"], as_index=False).agg({"JP_Sales":"mean"}).sort_values("JP_Sales", ascending=False)
    best_publisher_jp_res = best_publisher_jp.query("JP_Sales > 0")
    return best_publisher_jp_res

# %%
best_publisher_jp(get_data())
# Out:
#                        Publisher  JP_Sales
# 64                    SquareSoft  0.796250
# 52                      Nintendo  0.794000
# 24              Enix Corporation  0.540000
# 9                     Aruze Corp  0.500000
# 4            ASCII Entertainment  0.460000
# 30          Hudson Entertainment  0.440000
# 38                       Jorudan  0.300000
# 62                        Square  0.285000
# 60   Sony Computer Entertainment  0.269200
# 59                          Sega  0.262222
# 41  Konami Digital Entertainment  0.241250
# 14                     Banpresto  0.233333
# 70                         Taito  0.215000
# 21             Eidos Interactive  0.192500
# 33                     Imagineer  0.180000
# 28                         Genki  0.170000
# 16                      ChunSoft  0.160000
# 50            Namco Bandai Games  0.156429
# 32           Human Entertainment  0.150000
# 8                      Aqua Plus  0.130000
# 26                 From Software  0.130000
# ...

# %%
get_data()
# Out:
#         Rank                           Name Platform    Year         Genre  \
# 12        13    Pokemon Gold/Pokemon Silver       GB  1999.0  Role-Playing
# 69        70                 Gran Turismo 2       PS  1999.0        Racing
# 87        88             Final Fantasy VIII       PS  1999.0  Role-Playing
# 138      139                         Driver       PS  1999.0        Action
# 157      158              Super Smash Bros.      N64  1999.0      Fighting
# ...      ...                            ...      ...     ...           ...
# 16193  16196                 K-1 Grand Prix       PS  1999.0      Fighting
# 16195  16198                       Legoland       PC  1999.0        Action
# 16239  16242                Builder's Block       PS  1999.0      Strategy
# 16506  16509  Samurai Shodown: Warrios Rage       PS  1999.0      Fighting
# 16583  16586                 Carmageddon 64      N64  1999.0        Action
#
# ...

# %%
# Сколько игр продались лучше в Европе, чем в Японии?
#@task()
def games_eur_vs_jp(df):
    df['EurMoreThanJp'] = df.EU_Sales > df.JP_Sales
    games_eur_vs_jp_res = df.EurMoreThanJp.count()
    return games_eur_vs_jp_res

# %%
games_eur_vs_jp(get_data())
# Out:
# 338

# %%
#@task()
def print_data(bestseller_game, bestseller_games_euro, million_platform_na, best_publisher_jp, games_eur_vs_jp):
    
    date = ''

    print(f' Какая игра была самой продаваемой в этом году во всем мире? {date}')
    print(bestseller_game(df))
    print('------------')
    print(f' Игры какого жанра были самыми продаваемыми в Европе? {date}')
    print(bestseller_games_euro(df))
    print('------------')
    print(f' На какой платформе было больше всего игр, которые продались более чем миллионным тиражом в Северной Америке? {date}')
    print(million_platform_na(df))
    print('------------')
    print(f' У какого издателя самые высокие средние продажи в Японии? {date}')
    print(best_publisher_jp(df))
    print('------------')
    print(f' Сколько игр продались лучше в Европе, чем в Японии? {date}')
    print(games_eur_vs_jp(df))

# %%
print_data(bestseller_game, bestseller_games_euro, million_platform_na, best_publisher_jp, games_eur_vs_jp)
# Out:
#  Какая игра была самой продаваемой в этом году во всем мире?
# Wii Sports
# ------------
#  Игры какого жанра были самыми продаваемыми в Европе?
# Action, Sports, Shooter, Racing, Misc, Platform, Role-Playing, Simulation, Fighting, Adventure, Puzzle, Strategy
# ------------
#  На какой платформе было больше всего игр, которые продались более чем миллионным тиражом в Северной Америке?
#    Platform  MoreThan1M
# 28     X360      601.05
# 16      PS2      583.84
# 26      Wii      507.71
# 17      PS3      392.26
# 4        DS      390.71
# 15       PS      336.51
# 6       GBA      187.54
# 29       XB      186.69
# 10      N64      139.02
# 7        GC      133.46
# 11      NES      125.94
# 5        GB      114.32
# 19      PSP      108.99
# 18      PS4       96.80
# 13       PC       93.28
# 0      2600       90.60
# 30     XOne       83.19
# 2       3DS       78.87
# 23     SNES       61.23
# 27     WiiU       38.32
# 8       GEN       19.27
# 20      PSV       16.20
# ...
